# %%
# !git clone https://github.com/gokulprathin8/pygeoweaver 
# !cd pygeoweaver && git checkout v1/changes
# !cd pygeoweaver && git pull && pip3 install . --force-reinstall
# !rm -rf pygeoweaver
# !pip3 install dask
# Out:
# Cloning into 'pygeoweaver'...
# remote: Enumerating objects: 632, done.
# remote: Counting objects: 100% (200/200), done.
# remote: Compressing objects: 100% (108/108), done.
# remote: Total 632 (delta 113), reused 141 (delta 90), pack-reused 432
# Receiving objects: 100% (632/632), 96.32 KiB | 699.00 KiB/s, done.
# Resolving deltas: 100% (373/373), done.
# Branch 'v1/changes' set up to track remote branch 'v1/changes' from 'origin'.
# Switched to a new branch 'v1/changes'
# Already up to date.
# Processing /home/jovyan/pygeoweaver
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: pygeoweaver
#   Building wheel for pygeoweaver (pyproject.toml) ... done
#   Created wheel for pygeoweaver: filename=pygeoweaver-0.6.14-py3-none-any.whl size=18130 sha256=90c4a8bc5da55e0b837daf3949b9f1d157f93fec86d510ca9a79ebd9fee2f4be
#   Stored in directory: /tmp/pip-ephem-wheel-cache-285fjrue/wheels/93/a1/6e/a050f64e631c394967270cd06192bd4e9a47ecdf3c3487ff99
# Successfully built pygeoweaver
# Installing collected packages: pygeoweaver
#   Attempting uninstall: pygeoweaver
#     Found existing installation: pygeoweaver 0.6.14
#     Uninstalling pygeoweaver-0.6.14:
#       Successfully uninstalled pygeoweaver-0.6.14
# Successfully installed pygeoweaver-0.6.14
# Requirement already satisfied: dask in /srv/conda/envs/notebook/lib/python3.9/site-packages (2023.4.1)
# Requirement already satisfied: click>=8.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from dask) (8.1.3)
# Requirement already satisfied: cloudpickle>=1.5.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from dask) (2.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from dask) (2023.5.0)
# Requirement already satisfied: packaging>=20.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from dask) (23.1)
# Requirement already satisfied: partd>=1.2.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from dask) (1.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from dask) (6.0)
# Requirement already satisfied: toolz>=0.10.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from dask) (0.12.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from dask) (6.6.0)
# Requirement already satisfied: zipp>=0.5 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from importlib-metadata>=4.13.0->dask) (3.15.0)
# Requirement already satisfied: locket in /srv/conda/envs/notebook/lib/python3.9/site-packages (from partd>=1.2.0->dask) (1.0.0)

# %%
import pygeoweaver as gw

# %%
gw.start()
# Out:
# Stop running Geoweaver if any..
# Check Java..
# Start Geoweaver..
# Success: Geoweaver is up

# %%
gw.list_hosts()
# Out:
# +---------+-----------+-----------+------+------------+
# | Host Id | Hostname  | IP        | Port | Username   |
# +---------+-----------+-----------+------+------------+
# | 100001  | Localhost | 127.0.0.1 | 22   | publicuser |
# +---------+-----------+-----------+------+------------+

# %%
gw.import_workflow('/home/jovyan/kr2novmm4i9i27z5adyj.zip')
# Out:
# Unzipping /home/jovyan/gw-workspace/temp/kr2novmm4i9i27z5adyj.zip to /home/jovyan/gw-workspace/temp/kr2novmm4i9i27z5adyj/
# /home/jovyan/gw-workspace/temp/kr2novmm4i9i27z5adyj - /
# /home/jovyan/gw-workspace/temp/kr2novmm4i9i27z5adyj - history/process_wttkvt.json
# Precheck: Done
# Workflow ID: kr2novmm4i9i27z5adyj
# Successfully saved to database. Complete.

# %%
gw.list_workflows()
# Out:
# +-----------------------+-------------------------+
# | Workflow Id           | Name                    |
# +-----------------------+-------------------------+
# | gr3ykr8dynu12vrwq11oy | snowcast_wormhole500    |
# | kr2novmm4i9i27z5adyj  | earth_data_cloud_clinic |
# +-----------------------+-------------------------+

# %%
gw.list_processes()
# Out:
# +------------+-----------------------------------+----------+-------------+
# | Process Id | Name                              | Language | Description |
# +------------+-----------------------------------+----------+-------------+
# | 78vedq     | data_sentinel2                    | python   | -           |
# | mxpyqt     | model_creation_lstm               | python   | python      |
# | c2xkhz     | model_creation_rf                 | python   | -           |
# | rauqsh     | model_creation_ghostnet           | python   | python      |
# | mi3e5n     | model_comparison                  | python   | -           |
# | u7xh2p     | data_integration                  | python   | -           |
# | 2wkl6e     | service_deployment                | python   | python      |
# | i2fynz     | service_prediction                | python   | -           |
# | e8k4wq     | model_train_validate              | python   | -           |
# | h1qp9v     | model_predict                     | python   | -           |
# | urd0nk     | data_terrainFeatures              | python   | -           |
# | 525l8q     | data_gee_modis_station_only       | python   | -           |
# | 7temiv     | data_gee_sentinel1_station_only   | python   | -           |
# | rmxece     | data_associate_station_grid_cell  | python   | -           |
# | illwc1     | data_gee_modis_real_time          | python   | -           |
# | sjs5by     | data_gee_sentinel1_real_time      | python   | -           |
# | y7nb46     | base_hole                         | python   | -           |
# | a8p3n7     | data_gee_gridmet_station_only     | python   | -           |
# | smsdr0     | data_gee_gridmet_real_time        | python   | -           |
# | 4i0sop     | model_creation_xgboost            | python   | -           |
# | b63prf     | testing_data_integration          | python   | -           |
# | zh38b6     | snowcast_utils                    | python   | -           |
# | wdh394     | model_create_kehan                | python   | -           |
# | ilbqzg     | all_dependencies                  | python   | -           |
# | do86ae     | data_WUS_UCLA_SR                  | python   | python      |
# | gkhtc0     | data_nsidc_4km_swe                | python   | -           |
# | lbd6cp     | model_creation_et                 | python   | python      |
# | 8ovvln     | data_nsidc_4km_swe_testing        | python   | -           |
# | 8sv3o6     | gridmet_region_selection_download | python   | python      |
# | 11iolq     | gridmet_modis                     | python   | -           |
# | p87wh1     | data_snotel_real_time             | python   | -           |
# | oof81y     | ml_post_processing                | python   | python      |
# | drd3i0     | data_terrain_imagery              | python   | -           |
# | wttkvt     | earth_data_utils                  | python   | -           |
# | yvo1ds     | search_data                       | python   | -           |
# | cgvhiy     | earth_access_authenticate         | python   | -           |
# | v2ow93     | connect_harmony_client            | python   | -           |
# | 1b4ko0     | s3_file_storage                   | python   | -           |
# +------------+-----------------------------------+----------+-------------+

# %%
gw.list_hosts()
# Out:
# +---------+-----------+-----------+------+------------+
# | Host Id | Hostname  | IP        | Port | Username   |
# +---------+-----------+-----------+------+------------+
# | 100001  | Localhost | 127.0.0.1 | 22   | publicuser |
# +---------+-----------+-----------+------+------------+

# %%
import getpass
password = getpass.getpass()
# Out:
#  ········

# %%
gw.run_workflow(workflow_id='kr2novmm4i9i27z5adyj', host_list='100001', password_list=password)
# Out:
# Running workflow kr2novmm4i9i27z5adyj
# The workflow has been kicked off.
# History Id: mx1w8k46bha4zi0q8r
# Waiting for it to finish
# > Start to run process: wttkvt
# > Fnished process: wttkvt - history: up3kzptbd6u - Status: Done
# > Start to run process: yvo1ds
# > Fnished process: yvo1ds - history: 33tkamqsogz - Status: Done
# > Start to run process: cgvhiy
# > Fnished process: cgvhiy - history: 1d8qw3nj2gh - Status: Done
# > Start to run process: v2ow93
# > Fnished process: v2ow93 - history: o9rugig6e7k - Status: Done
# > Start to run process: 1b4ko0
# > Fnished process: 1b4ko0 - history: mvmf00065id - Status: Done
# Total time cost: 2006 seconds
# Execution is over. Final status: Done.

# %%
gw.get_workflow_history('kr2novmm4i9i27z5adyj')
# Out:
#             history_id                                      history_input
# 0   mx1w8k46bha4zi0q8r  wttkvt-GJjq8;yvo1ds-96vns;cgvhiy-BgnXM;v2ow93-...  \
# 1   6hxs1emptzyrmsi0f3  wttkvt-GJjq8;yvo1ds-96vns;cgvhiy-BgnXM;v2ow93-...
# 2   5uzqmkhig32ub23cax  wttkvt-GJjq8;yvo1ds-96vns;cgvhiy-BgnXM;v2ow93-...
# 3   ywrvvwo20iif52rga6  wttkvt-GJjq8;yvo1ds-96vns;cgvhiy-BgnXM;v2ow93-...
# 4   fbSMCmb9pAMK1bogT0  wttkvt-GJjq8;yvo1ds-96vns;cgvhiy-BgnXM;v2ow93-...
# 5   b8oEcCvvIU6KaKiYoT  wttkvt-GJjq8;yvo1ds-96vns;cgvhiy-BgnXM;v2ow93-...
# 6   QBaTZsjXUzZrYyaSGY  wttkvt-GJjq8;yvo1ds-96vns;cgvhiy-BgnXM;v2ow93-...
# 7   lwpewb4927s4e4m49r  wttkvt-GJjq8;yvo1ds-96vns;cgvhiy-BgnXM;v2ow93-...
# 8   KeJgbxTIefDdZTHTLf  wttkvt-GJjq8;yvo1ds-96vns;cgvhiy-BgnXM;v2ow93-...
# 9   vC36VuDH7D6OOMF68w  wttkvt-GJjq8;yvo1ds-96vns;cgvhiy-BgnXM;v2ow93-...
# 10  lxABhFBxbAvzawPiKs  wttkvt-GJjq8;yvo1ds-96vns;cgvhiy-BgnXM;v2ow93-...
# 11  wDqF0CmSx2MfoE037z  wttkvt-GJjq8;yvo1ds-96vns;cgvhiy-BgnXM;v2ow93-...
# 12  c3lYCsxly0BDlEg6da  wttkvt-GJjq8;yvo1ds-96vns;cgvhiy-BgnXM;v2ow93-...
# 13  mr9YcFRUnuNyThJb4Q  wttkvt-GJjq8;yvo1ds-96vns;cgvhiy-BgnXM;v2ow93-...
# 14  kX9THeiXUlECn7qnLK  wttkvt-GJjq8;yvo1ds-96vns;cgvhiy-BgnXM;v2ow93-...
# 15  a4t3g4kcmx2j5iggfu  wttkvt-GJjq8;yvo1ds-96vns;cgvhiy-BgnXM;v2ow93-...
# 19  rm0v06cmvuc;8nq18ogdwdi;jhzwkhohmz7;6o2p0699ri...       1686240517776
# 20  15jtnmmliz8;sj2llldbybq;alm4h4h5irw;fs47znp6yg...       1686240486441
# 21  5gi96g5psgp;7ikdfl3nkyj;zftnvonktj6;aipjqmvzj5...       1686240367658
# 22  ro72gckii7a;dnqed48moze;xb7v9iap72l;8heewks755...       1686240350800
# 23  9a06gtkzws7;4z8l2w2pq5n;2z9k699i4su;w8f5ftv7f9...       1686240315441
#
#     history_end_time history_notes       history_process  host_id indicator
# 0       1.686248e+12          None  kr2novmm4i9i27z5adyj  100001;      Done
# 1       1.686246e+12          None  kr2novmm4i9i27z5adyj  100001;   Running
# 2       1.686246e+12          None  kr2novmm4i9i27z5adyj  100001;   Running
# 3       1.686246e+12          None  kr2novmm4i9i27z5adyj  100001;   Running
# 4       1.686246e+12          None  kr2novmm4i9i27z5adyj  100001;      Done
# 5       1.686243e+12          None  kr2novmm4i9i27z5adyj  100001;    Failed
# 6       1.686243e+12          None  kr2novmm4i9i27z5adyj  100001;    Failed
# 7       1.686242e+12          None  kr2novmm4i9i27z5adyj  100001;    Failed
# 8       1.686242e+12          None  kr2novmm4i9i27z5adyj  jf7wuu;   Stopped
# 9       1.686241e+12          None  kr2novmm4i9i27z5adyj  100001;    Failed
# 10      1.686241e+12          None  kr2novmm4i9i27z5adyj  100001;    Failed
# 11      1.686241e+12          None  kr2novmm4i9i27z5adyj  100001;      Done
# 12      1.686241e+12          None  kr2novmm4i9i27z5adyj  100001;      Done
# 13               NaN          None  kr2novmm4i9i27z5adyj  jf7wuu;   Stopped
# 14               NaN          None  kr2novmm4i9i27z5adyj  jf7wuu;   Stopped
# 15      1.686241e+12          None  kr2novmm4i9i27z5adyj  100001;    Failed
# 16      1.686241e+12          None  kr2novmm4i9i27z5adyj  100001;    Failed
# 17      1.686241e+12          None  kr2novmm4i9i27z5adyj  100001;    Failed
# 18      1.686241e+12          None  kr2novmm4i9i27z5adyj  100001;    Failed
# 19      1.686241e+12          None  kr2novmm4i9i27z5adyj  jf7wuu;    Failed
# 20      1.686240e+12          None  kr2novmm4i9i27z5adyj  jf7wuu;    Failed
# 21               NaN          None  kr2novmm4i9i27z5adyj  jf7wuu;   Stopped
# 22               NaN          None  kr2novmm4i9i27z5adyj  jf7wuu;   Stopped
# 23               NaN          None  kr2novmm4i9i27z5adyj  jf7wuu;   Stopped

# %%
gw.get_process_history('1b4ko0')
# Out:
#      history_id                                      history_input
# 0   mvmf00065id  from connect_harmony_client import *\n\ntry:\n...  \
# 1   ko8yqm9aivh  from connect_harmony_client import *\n\ncreds ...
# 2   v4ntpteua2l  from connect_harmony_client import *\n\ncreds ...
# 3   27lzj9wau2o  from connect_harmony_client import *\n\ncreds ...
# 4   d3nhdcgfyv5  from connect_harmony_client import *\n\ncreds ...
# 5   f790nxhc4qr  from connect_harmony_client import *\n\ncreds ...
# 6   4khylyjgoe4  from connect_harmony_client import *\n\ncreds ...
# 7   0bkcl1klyxx  from connect_harmony_client import *\n\ncreds ...
# 8   la04lix4c0q  from connect_harmony_client import *\n\ncreds ...
# 9   58l7pi2q4u8  from connect_harmony_client import *\n\ncreds ...
# 10  xppy6yerx8m  from connect_harmony_client import *\n\ncreds ...
# 11  ke2j3drtb6q  from connect_harmony_client import *\n\ncreds ...
# 12  27jwzml5k5j  from connect_harmony_client import *\n\ncreds ...
# 13  y60lziviqpo                                               None
# 14  jzfcnc2x9ld                                               None
# 15  8hsxxxpewlc                                               None
# 16  gdth48an9nl                                               None
# 17  ngiu5l6fplt                                               None
# 18  79d54cll9uy                                               None
# 19  25ge8xlhrh8                                               None
# 20  20ieoc7wueo                                               None
#
#                                        history_output  history_begin_time
# 0   /srv/conda/envs/notebook/lib/python3.9/site-pa...        1.686248e+12  \
# 1                                             Running        1.686246e+12
# 2   /srv/conda/envs/notebook/lib/python3.9/site-pa...        1.686243e+12
# 3   /srv/conda/envs/notebook/lib/python3.9/site-pa...        1.686243e+12
# 4   /srv/conda/envs/notebook/lib/python3.9/site-pa...        1.686242e+12
# 5   Traceback (most recent call last):\n  File "/h...        1.686242e+12
# 6   Traceback (most recent call last):\n  File "/U...        1.686241e+12
# 7   Traceback (most recent call last):\n  File "/U...        1.686241e+12
# 8   Traceback (most recent call last):\n  File "/U...        1.686241e+12
# 9   /srv/conda/envs/notebook/lib/python3.9/site-pa...        1.686241e+12
# 10  Traceback (most recent call last):\n  File "/U...        1.686241e+12
# 11  Traceback (most recent call last):\n  File "/U...        1.686241e+12
# 12  Traceback (most recent call last):\n  File "/U...        1.686241e+12
# 13                                               None                 NaN
# 14                                               None                 NaN
# 15                                               None                 NaN
# 16                                               None                 NaN
# 17                                               None                 NaN
# 18                                               None                 NaN
# 19                                               None                 NaN
# 20                                               None                 NaN
#
#     history_end_time history_notes history_process host_id indicator
# 0      1686248388682          None          1b4ko0  100001      Done
# 1      1686245774193          None          1b4ko0  100001      Done
# 2      1686242839291          None          1b4ko0  100001    Failed
# 3      1686242627886          None          1b4ko0  100001    Failed
# 4      1686242262431          None          1b4ko0  100001    Failed
# 5      1686244617718          None          1b4ko0  jf7wuu   Stopped
# 6      1686241489095          None          1b4ko0  100001    Failed
# 7      1686241468599          None          1b4ko0  100001    Failed
# 8      1686241412628          None          1b4ko0  100001   Stopped
# 9      1686241229124          None          1b4ko0  100001    Failed
# 10     1686240687124          None          1b4ko0  100001    Failed
# 11     1686240638505          None          1b4ko0  100001    Failed
# 12     1686240571828          None          1b4ko0  100001    Failed
# 13     1686240359463          None          1b4ko0  jf7wuu   Stopped
# 14     1686240523326          None          1b4ko0  jf7wuu   Stopped
# 15     1686240331457          None          1b4ko0  jf7wuu   Stopped
# 16     1686240496418          None          1b4ko0  jf7wuu   Stopped
# 17     1686240477217          None          1b4ko0  jf7wuu   Stopped
# 18     1686241361745          None          1b4ko0  jf7wuu   Stopped
# 19     1686241339097          None          1b4ko0  jf7wuu   Stopped
# 20     1686241372961          None          1b4ko0  100001   Stopped
